# %%
from src.text_processing.headers_evaluator import HeadersEvaluator

# %%
evaluator = HeadersEvaluator()

results_df, summary_df = evaluator.evaluate()
# Out:
# Обработка: article_1.pdf
# Обработка: article_10.pdf
# Обработка: article_11.pdf
# Обработка: article_12.pdf
# Обработка: article_13.pdf
# Обработка: article_14.pdf
# Обработка: article_15.pdf
# Обработка: article_16.pdf
# Обработка: article_17.pdf
# Обработка: article_18.pdf
# Обработка: article_19.pdf
# Обработка: article_2.pdf
# Обработка: article_20.pdf
# Обработка: article_3.pdf
# Обработка: article_4.pdf
# Обработка: article_5.pdf
# Обработка: article_6.pdf
# Обработка: article_7.pdf
# Обработка: article_8.pdf
# Обработка: article_9.pdf

# %%
display(summary_df.sort_values("f1", ascending=False))
# Out:
#            method  documents   TP    FP  FN  precision  recall      f1  \
# 1  MinerU + rules         20  101     9  55     0.9182  0.6474  0.7594
# 0      MinerU raw         20  128    93  28     0.5792  0.8205  0.6790
# 4     mixed_clean         20  119   270  37     0.3059  0.7628  0.4367
# 3   MuPDF + rules         20   93   260  63     0.2635  0.5962  0.3654
# 2       MuPDF raw         20  100  1899  56     0.0500  0.6410  0.0928
#
#    macro_precision  macro_recall  macro_f1
# 1           0.9464        0.6491    0.7131
# 0           0.5772        0.8413    0.6584
# 4           0.5461        0.7392    0.5461
# 3           0.5009        0.6167    0.4722
# 2           0.0939        0.7159    0.1602

# %%
evaluator.plot_all(results_df, summary_df)
